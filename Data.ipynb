# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from keras.datasets import cifar10
sns.set(style='white', context='notebook', palette='deep')
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Cifar-10

# %% [markdown]
# ### Load data

# %%
# Set the random seed
random_seed = 135791113

def load_data():
    (x_train, y_train), (x_test, y_test) = cifar10.load_data()
    X_train = x_train.astype('float32')
    X_test = x_test.astype('float32')
    return X_train, y_train, X_test, y_test

CLASSES = 10
X_train, Y_train, X_test, Y_test = load_data()

# %%
print("Training samples {}".format(X_train.shape))
print("Training labels {}".format(Y_train.shape))
print("Testing samples {}".format(X_test.shape))
print("Testing labels {}".format(Y_test.shape))
# Out:
# Training samples (50000, 32, 32, 3)
# Training labels (50000, 1)
# Testing samples (10000, 32, 32, 3)
# Testing labels (10000, 1)

# %% [markdown]
# ### Data Distribution

# %%
g = sns.countplot(Y_train.reshape(1,-1)[0])

# %%
g = sns.countplot(Y_test.reshape(1,-1)[0])

# %% [markdown]
# ### Examples

# %%
# Some examples  
f, axarr = plt.subplots(2,2)
axarr[0,0].imshow(X_train[0]/ 255.0)
axarr[0,1].imshow(X_train[1]/ 255.0)
axarr[1,0].imshow(X_train[2]/ 255.0)
axarr[1,1].imshow(X_train[3]/ 255.0)

# %% [markdown]
# # Minst

# %%
from utils import load_mnist

# Load data here

# %% [markdown]
# ### I think we should explore this dataset a little bit
# * How many samples do we have?
# * How do the images look?
# * Anything else?
